# %%
import sys
from pathlib import Path

ROOT = Path().resolve().parents[0]  # если скрипт, а не ноутбук
# в ноутбуке можно так:
# ROOT = Path().resolve()

sys.path.append(str(ROOT / "src"))

# %%
# Координаты Новороссийска
LATITUDE = 44.72439
LONGITUDE = 37.76752

# Период данных (ERA5-Land доступна с 1950, обновляется с задержкой 5 дней)
START_DATE = "2026-02-15"
# END_DATE = "2026-02-01"

# %%
from whether import Whether

whether = Whether(longitude=LONGITUDE, latitude=LATITUDE)

# %%
whether.download_whether_data(start_date="2025-12-15", end_date="2026-01-01", timeout=5)
# whether.download_whether_data(start_date="2026-01-15", timeout=5)
whether.whether_data
# Out:
#           date  temperature_2m_max  temperature_2m_min  \
# 0   2025-12-15                 8.6                 3.3
# 1   2025-12-16                 3.1                 0.7
# 2   2025-12-17                10.2                 0.4
# 3   2025-12-18                10.3                 5.0
# 4   2025-12-19                12.0                 6.4
# 5   2025-12-20                10.2                 4.4
# 6   2025-12-21                 9.6                 3.7
# 7   2025-12-22                 7.6                 3.3
# 8   2025-12-23                 6.3                 3.4
# 9   2025-12-24                 4.9                 1.0
# 10  2025-12-25                 0.5                -4.6
# 11  2025-12-26                 5.5                -3.8
# 12  2025-12-27                 3.6                 0.3
# 13  2025-12-28                 5.8                -0.8
# 14  2025-12-29                 3.6                 0.9
# 15  2025-12-30                 7.5                 1.0
# ...

# %%
# whether.export_whether_data(file_path="whether.json")
# whether.export_whether_data(file_path="whether.csv")
# whether.export_whether_data(file_path="whether.xlsx")

# %%
whether_2 = Whether(longitude=LONGITUDE, latitude=LATITUDE)
whether_2.read_whether_data("whether.json")
whether_2.read_whether_data("whether.csv")
whether_2.read_whether_data("whether.xlsx")
whether_2.whether_data
# Out:
#          date  temperature_2m_max  temperature_2m_min  \
# 0  2026-01-15                 4.6                 0.4
# 1  2026-01-16                -0.3                -3.2
# 2  2026-01-17                -3.6                -7.9
# 3  2026-01-18                -3.0                -6.0
# 4  2026-01-19                -4.3                -7.5
# 5  2026-01-20                -2.6                -9.9
# 6  2026-02-15                12.5                 7.9
# 7  2026-02-16                13.4                 9.2
# 8  2026-02-17                 NaN                 NaN
#
#    apparent_temperature_max  apparent_temperature_min  precipitation_sum  \
# 0                       0.8                      -4.8               13.7
# 1                      -4.4                      -8.1                3.2
# 2                      -8.9                     -14.8                2.6
# 3                     -10.2                     -13.1                0.0
# ...

# %%
whether.whether_data
# Out:
#           date  temperature_2m_max  temperature_2m_min  \
# 0   2025-12-15                 8.6                 3.3
# 1   2025-12-16                 3.1                 0.7
# 2   2025-12-17                10.2                 0.4
# 3   2025-12-18                10.3                 5.0
# 4   2025-12-19                12.0                 6.4
# 5   2025-12-20                10.2                 4.4
# 6   2025-12-21                 9.6                 3.7
# 7   2025-12-22                 7.6                 3.3
# 8   2025-12-23                 6.3                 3.4
# 9   2025-12-24                 4.9                 1.0
# 10  2025-12-25                 0.5                -4.6
# 11  2025-12-26                 5.5                -3.8
# 12  2025-12-27                 3.6                 0.3
# 13  2025-12-28                 5.8                -0.8
# 14  2025-12-29                 3.6                 0.9
# 15  2025-12-30                 7.5                 1.0
# ...

# %%
whether.get_statistic_df()
# Out:
#        temperature_2m_max  temperature_2m_min  apparent_temperature_max  \
# count           26.000000           26.000000                 26.000000
# mean             5.034615            0.242308                  0.861538
# std              5.137154            4.836128                  6.347540
# min             -4.300000           -9.900000                -11.900000
# 25%              2.125000           -2.875000                 -2.650000
# 50%              5.200000            0.650000                  0.400000
# 75%              9.350000            3.375000                  6.550000
# max             13.400000            9.200000                 10.800000
#
#        apparent_temperature_min  precipitation_sum   rain_sum  snowfall_sum  \
# count                 26.000000          26.000000  26.000000     26.000000
# mean                  -4.388462           1.938462   1.138462      0.560000
# std                    6.312991           3.222059   2.101252      1.318975
# ...

# %%
whether.read_whether_data("whether.xlsx")
# Out:
#         date  temperature_2m_max  temperature_2m_min  \
# 0 2026-01-15                 4.6                 0.4
# 1 2026-01-16                -0.3                -3.2
# 2 2026-01-17                -3.6                -7.9
# 3 2026-01-18                -3.0                -6.0
# 4 2026-01-19                -4.3                -7.5
# 5 2026-01-20                -2.6                -9.9
# 6 2026-02-15                12.5                 7.9
# 7 2026-02-16                13.4                 9.2
# 8 2026-02-17                 NaN                 NaN
#
#    apparent_temperature_max  apparent_temperature_min  precipitation_sum  \
# 0                       0.8                      -4.8               13.7
# 1                      -4.4                      -8.1                3.2
# 2                      -8.9                     -14.8                2.6
# 3                     -10.2                     -13.1                0.0
# ...
